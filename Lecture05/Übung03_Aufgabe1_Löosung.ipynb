# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 200

# %%
data = np.genfromtxt("Data2.txt", skip_header=19, skip_footer=50)
plt.plot(data[:,0], data[:,1])

# %%
data = np.genfromtxt("Data3.dat", skip_header=1)

# %%
plt.imshow(data[1:,1:].T, cmap = 'hot', extent=[-5.400000, -5.200000,449.998841,808.182848,],aspect="auto")
plt.xlabel('Time (ps)')
plt.ylabel('Wavelength (nm)')
# Out:
# Text(0,0.5,'Wavelength (nm)')

# %%
plt.plot(data[0,5:], data[500,5:])
#plt.plot(data[0,5:], data[600,5:])

plt.ylabel('Intentsity (au)')
plt.xlabel('Wavelength (nm)')
# Out:
# Text(0.5,0,'Wavelength (nm)')

# %%
plt.plot(data[1:,0], data[1:,100])
plt.ylabel('Intentsity (au)')
plt.xlabel('Time (ps)')
# Out:
# Text(0.5,0,'Time (ps)')

# %%
plt.plot(data[1:,0], data[1:,100])
#plt.plot(data[1:,0], data[1:,150])
plt.xlim(-5.3, -5.29)
plt.ylabel('Intentsity (au)')
plt.xlabel('Time (ps)')
# Out:
# Text(0.5,0,'Time (ps)')

# %%
data = np.genfromtxt("Data4.txt", skip_header=1)
plt.plot(data[:,0], data[:,1])
plt.plot(data[:,0], data[:,2])
plt.plot(data[:,0], data[:,3])
#plt.plot(data[:,0], data[:,4])

plt.xlabel('Time (ps)')
plt.ylabel('Voltage (mV)')
# Out:
# Text(0,0.5,'Voltage (mV)')

# %%
data = np.genfromtxt("Data5.txt", comments='~')
plt.title('Ellipsometry')

plt.xlabel('Wavelength (nm)')
plt.ylabel('Refractive Index')
plt.plot(data[:-5,0], data[:-5,1], label = ('n'))
plt.plot(data[:-5,0], data[:-5,2], label = ('k'))
plt.legend()
